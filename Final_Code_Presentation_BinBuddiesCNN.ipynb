# %% [markdown]
# <a href="https://colab.research.google.com/github/yvessong23/ML-TEAM-15/blob/main/Final_Code_Presentation_BinBuddiesCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import TensorFlow
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, roc_auc_score
import seaborn as sns

# %%
# %pip install numpy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import hashlib, os
from PIL import Image
# %pip install kagglehub

import kagglehub

# Download latest version
path = kagglehub.dataset_download("zlatan599/garbage-dataset-classification")
rgb_path = "cleaned/garbage-dataset-rgb"
print("Path to dataset files:", path)

hashes = {}
duplicates = []

def file_hash(filePath):
    with open(filePath, "rb") as f: # Open and read files for hashing
        file_bytes = f.read()
        return hashlib.md5(file_bytes).hexdigest()

for root, dirs, files in os.walk(path):
    for file in files:
        file_path = os.path.join(root, file)
        h = file_hash(file_path)

        if h in hashes:
            print(f"Duplicate found! Removing {file_path} (same as {hashes[h]})")
            try:
                os.remove(file_path)
                duplicates.append((file_path, hashes[h]))
            except OSError as e:
                print(f"Warning: Could not remove {file_path} due to read-only filesystem. Error: {e}")
        else:
            hashes[h] = file_path
            try:
                # Preserve the dataset’s subfolder structure
                rel_dir = os.path.relpath(root, path)
                save_dir = os.path.join(rgb_path, rel_dir)
                os.makedirs(save_dir, exist_ok=True)

                save_path = os.path.join(save_dir, file)

                # Skip non-image files (like metadata.csv)
                if not file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff")):
                    continue

                with Image.open(file_path) as img:
                    img.convert("RGB").save(save_path)

            except Exception as e:
                print(f"Error processing {file_path}: {e}")
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.11.12)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/zlatan599/garbage-dataset-classification?dataset_version_number=5...
# 100%|██████████| 121M/121M [00:04<00:00, 26.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02169.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00439.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00493.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02276.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02209.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00128.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02248.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03147.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02235.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01478.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00633.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02322.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01283.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02703.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03304.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02214.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02428.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00258.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02341.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00064.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02234.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00013.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02666.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00448.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00025.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02284.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02136.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00594.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02486.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00299.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01595.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02556.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01783.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02124.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01814.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02498.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00889.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02148.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02269.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01454.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03110.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02529.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02156.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00414.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02503.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00790.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00230.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02350.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02488.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00004.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02642.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01997.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02311.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02017.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02496.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03220.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02129.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03231.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02118.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00254.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02362.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00532.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00234.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02139.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01835.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02259.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02324.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01007.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02659.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00302.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02600.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00690.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00778.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02142.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01378.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02461.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02691.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00966.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02117.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00739.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00075.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02399.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03222.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02364.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03278.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02440.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01638.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02504.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02301.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00401.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02419.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02069.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00227.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02464.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00783.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02403.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02664.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01423.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02147.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00054.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02321.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03197.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02521.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03237.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00068.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02150.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00008.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02678.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00279.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02578.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02256.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01077.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02355.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00074.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00303.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02441.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00345.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02153.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02228.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01186.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02411.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00080.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01008.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02401.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02694.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03308.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02579.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00143.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02177.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00444.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02483.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00220.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00490.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02283.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02189.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00067.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01379.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02310.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02449.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00610.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02391.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01071.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00385.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02647.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02305.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01455.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01978.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02212.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00123.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02386.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00550.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02607.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02620.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01414.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01588.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02348.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00507.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02619.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01705.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02251.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02218.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03043.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02339.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00324.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02473.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00888.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00005.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02384.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02684.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01262.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02291.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00880.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02408.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01106.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01529.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02625.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02207.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03104.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00380.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02662.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01747.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02191.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00705.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02645.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02393.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00433.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02681.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01467.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02675.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00488.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02584.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00167.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02288.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00195.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01994.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02185.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02336.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01600.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02489.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01470.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02435.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01428.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03163.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02421.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03259.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02626.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00044.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02484.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00655.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02268.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01193.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02253.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02366.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01764.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01530.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02604.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00313.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02434.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02519.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00541.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02430.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00642.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00400.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02522.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02573.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00829.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00603.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02262.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00895.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02574.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01295.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02536.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01499.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02555.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02340.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03151.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01150.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02112.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02422.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00097.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00529.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02211.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00212.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02597.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00522.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02589.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02221.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01111.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02365.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03250.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01374.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02514.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01792.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02474.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02257.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00549.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00731.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02186.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00407.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02413.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03297.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02427.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02475.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00586.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00117.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02343.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01321.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02363.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01744.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02241.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01389.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02575.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02442.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00863.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00478.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02243.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00115.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02590.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02110.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01253.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00870.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02599.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02330.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01355.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02157.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00273.jpg)
# ...
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02448.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01055.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01294.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02179.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01942.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02278.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02405.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01725.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02411.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01162.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03069.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02335.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00121.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02460.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02434.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00450.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00754.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02661.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01485.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02782.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01916.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02794.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02408.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01075.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02301.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00321.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00510.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02101.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02182.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00874.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02644.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00670.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02531.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00019.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00123.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02162.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02399.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01021.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02428.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01058.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00974.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02127.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02622.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01117.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01334.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02664.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02218.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01180.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02153.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03149.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02308.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01210.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02528.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00421.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02096.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00100.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03110.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02557.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01970.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02580.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02231.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00226.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02666.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00888.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01480.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02146.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01622.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02270.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00972.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02785.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00374.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02361.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00238.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02216.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02629.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00913.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02191.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00938.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02131.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03049.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01144.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02504.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02612.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00992.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00906.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02433.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01905.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02364.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00365.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02268.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02333.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01471.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02745.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01279.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00636.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02439.jpg)

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

rgb_path = "cleaned/garbage-dataset-rgb"
base_path = os.path.join(rgb_path, "Garbage_Dataset_Classification", "images")
DATASET_DIR = base_path

# Set up class names
class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
num_classes = len(class_names)

if 'duplicates' not in globals():
    duplicates = []

# Verify and collect all image paths and their labels
image_paths = []
labels = []

duplicate_filepaths = {f[0] for f in duplicates} # Extract only the file paths from the duplicates list

for class_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(base_path, class_name)
    if os.path.exists(class_dir):
        class_images = [f for f in os.listdir(class_dir)
                       if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
        print(f"{class_name}: {len(class_images)} images")

        for img_file in class_images:
            full_path = os.path.join(class_dir, img_file)
            if full_path not in duplicate_filepaths: # Only add if not a duplicate
                image_paths.append(full_path)
                labels.append(class_idx)
    else:
        print(f"Warning: {class_dir} does not exist")
# Out:
# cardboard: 1718 images
# glass: 2294 images
# metal: 1627 images
# paper: 1809 images
# plastic: 1709 images
# trash: 2500 images

# %% [markdown]
# # Hyper parameter Testing

# %%
# Hyperparameters for searching with Optuna
BLOCK_NUM = [3,4,5]
CONV_LAYERS = [1, 2, 3]
BATCH_SIZES = [16, 32, 64]
EPOCHS = [10, 20, 30]
CONV_LAYER_SIZE_BASE = [32, 64, 128]
FILTERS_SIZE = [3,5,7]
REGULARIZATION_CONST = [0.001, 0.01, 0.1]
REG_TYPE = ["n/a", "L2", "Dropout", "Both"]

# %%
# %pip install optuna
# import optuna
# import tensorflow as tf
# from tensorflow.keras import models, layers, regularizers

# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)
# BATCH_SIZE = 32
# from tensorflow.keras import models, layers
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# from sklearn.model_selection import train_test_split
# import numpy as np

# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# IMG_SIZE   = (IMG_HEIGHT, IMG_WIDTH)
# BATCH_SIZE = 32

# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     validation_split=0.3
# )

# val_test_datagen = ImageDataGenerator(
#     rescale=1./255,
#     validation_split=0.2
# )

# train_generator = train_datagen.flow_from_directory(
#     DATASET_DIR,
#     target_size=IMG_SIZE,
#     batch_size=BATCH_SIZE,
#     class_mode='categorical',
#     subset='training',
#     shuffle=True,
#     seed=42
# )

# # Load all validation images into memory, then split into val + test
# val_generator_full = val_test_datagen.flow_from_directory(
#     DATASET_DIR,
#     target_size=IMG_SIZE,
#     batch_size=1,
#     class_mode='categorical',
#     subset='validation',
#     shuffle=False,
#     seed=42
# )

# val_data = []
# val_labels = []

# for i in range(len(val_generator_full)):
#     x, y = val_generator_full[i]
#     val_data.append(x[0])
#     val_labels.append(y[0])

# val_data = np.array(val_data)
# val_labels = np.array(val_labels)

# X_val, X_test, y_val, y_test = train_test_split(
#     val_data,
#     val_labels,
#     test_size=0.5,
#     random_state=42,
#     stratify=np.argmax(val_labels, axis=1)
# )

# val_generator_data = (X_val, y_val)
# test_generator_data = (X_test, y_test)



# def build_model(trial):

#     block_num   = trial.suggest_categorical("block_num", [3, 4, 5])
#     conv_layers = trial.suggest_categorical("conv_layers", [1, 2, 3])
#     batch_size  = trial.suggest_categorical("batch_size", [16, 32, 64])
#     epochs      = trial.suggest_categorical("epochs", [10, 20, 30])
#     reg_type    = trial.suggest_categorical("reg_type", ["n/a", "L2", "Dropout", "Both"])

#     # example: choose regularizer based on reg_type
#     if reg_type in ["L2", "Both"]:
#         reg = regularizers.l2(trial.suggest_float("l2_reg", 1e-5, 1e-2, log=True))
#     else:
#         reg = None

#     dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5) if reg_type in ["Dropout", "Both"] else 0.0

#     # Hyperparameters to tune
#     f1 = trial.suggest_categorical("f1", [32, 48, 64])
#     f2 = trial.suggest_categorical("f2", [64, 96, 128])
#     f3 = trial.suggest_categorical("f3", [128, 192, 256])
#     f4 = trial.suggest_categorical("f4", [256, 384, 512])

#     d1 = trial.suggest_float("d1", 0.1, 0.4)
#     d2 = trial.suggest_float("d2", 0.1, 0.4)
#     d3 = trial.suggest_float("d3", 0.2, 0.5)
#     d4 = trial.suggest_float("d4", 0.2, 0.5)

#     dense_units = trial.suggest_categorical("dense_units", [128, 256, 512])
#     l2_reg = trial.suggest_float("l2_reg", 1e-5, 1e-2, log=True)
#     lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)

#     kernel = trial.suggest_categorical("kernel", [3, 5])

#     model = models.Sequential([
#         layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

#         layers.Conv2D(f1, (kernel, kernel), padding='same', activation='relu'),
#         layers.Conv2D(f2, (kernel, kernel), padding='same', activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dropout(d1),
#         layers.MaxPool2D(2),

#         layers.Conv2D(f3, (kernel, kernel), padding='same', activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dropout(d2),
#         layers.MaxPool2D(2),

#         layers.Conv2D(f4, (3,3), padding='same', activation='relu',
                      # kernel_regularizer=regularizers.l2(l2_reg)),
    #     layers.BatchNormalization(),
    #     layers.Dropout(d3),
    #     layers.MaxPool2D(2),

    #     layers.GlobalAveragePooling2D(),

    #     layers.Dense(dense_units, activation='relu',
    #                  kernel_regularizer=regularizers.l2(l2_reg)),
    #     layers.BatchNormalization(),
    #     layers.Dropout(d4),

    #     layers.Dense(6, activation='softmax')
    # ])

    # model.compile(
    #     optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
    #     loss='categorical_crossentropy',
    #     metrics=['accuracy']
    # )

    # return model
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 8.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
# def objective(trial):
#     model = build_model(trial)

#     history = model.fit(
#         train_generator,
#         validation_data=val_generator_data,
#         epochs=trial.params["epochs"],
#         batch_size=trial.params["batch_size"],
#         verbose=0
#     )

#     return history.history["val_loss"][-1]

# %%
# study = optuna.create_study(
#     direction="minimize",
#     pruner=optuna.pruners.MedianPruner(n_warmup_steps=3)
# )
# study.optimize(objective, n_trials=30)

# print("Best params:", study.best_params)

# %% [markdown]
# # Base Model Testing

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split
import numpy as np

IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_SIZE   = (IMG_HEIGHT, IMG_WIDTH)
BATCH_SIZE = 32

# comment our data augmentation as we found this resulted in lower accuracy
train_datagen = ImageDataGenerator(
    rescale=1./255,
    # rotation_range=20,
    # zoom_range=0.2,
    # horizontal_flip=True,
    # brightness_range=(0.7, 1.3)
)

val_test_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

# Load all validation images into memory, then split into val + test
val_generator_full = val_test_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=1,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=42
)

val_data = []
val_labels = []

for i in range(len(val_generator_full)):
    x, y = val_generator_full[i]
    val_data.append(x[0])
    val_labels.append(y[0])

val_data = np.array(val_data)
val_labels = np.array(val_labels)

X_val, X_test, y_val, y_test = train_test_split(
    val_data,
    val_labels,
    test_size=0.5,
    random_state=42,
    stratify=np.argmax(val_labels, axis=1)
)

val_generator_data = (X_val, y_val)
test_generator_data = (X_test, y_test)

# CNN GAP MODEL
# Convolutional blocks
# Batch Normalization for stability
# MaxPooling for spatial reduction
# L2 regularization to reduce overfitting
model_gap = models.Sequential([
    layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

    # Block 1
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),
    layers.MaxPool2D(2),

    # Block 2
    layers.Conv2D(128, (5,5), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),
    layers.MaxPool2D(2),

    # Block 3
    layers.Conv2D(256, (3,3), padding='same', activation='relu',
    kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.35),
    layers.MaxPool2D(2),

    # Block 4
    layers.Conv2D(512, (3,3), padding='same', activation='relu',
    kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.35),
    layers.MaxPool2D(2),

    # Head with GAP
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.50),
    layers.Dense(6, activation='softmax'),
])
# Out:
# Found 11657 images belonging to 6 classes.
# Found 2328 images belonging to 6 classes.

# %% [markdown]
# # Testing CNN with Global Average Pooling
#
# Using ChatGPT and Kaggle, I found that GAP or Global Average Pooling can significantly reduce the number of parameters. This method compresses each feature map into a single value by averaging its activations (outputs). This reduced our dimensionality from 34+ million to about 1.8M. This also allows the model to generalize better and train faster.
# https://www.kaggle.com/code/faressayah/cifar-10-images-classification-using-cnns-88
# https://www.kaggle.com/code/zlatan599/f1-0-97-garbage-classif-final-version-2
#
# Baseline model run with no data augmentation or dropout to compare to:
#
# Train Accuracy: 0.5875
#
# Train Loss: 1.3597
#
# Best Validation Accuracy: 0.4210 (Epoch 7)
#
# Best Validation Loss: 1.7832 (Epoch 7)
#
# Test Accuracy:: 0.4261
#
# Test Loss: 1.8093

# %%
print(tf.config.list_physical_devices("GPU"))

model_gap.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model_gap.summary()

checkpoint = ModelCheckpoint(
    'best_model_gap.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)


history_gap = model_gap.fit(
    train_generator,
    validation_data=val_generator_data,
    epochs=80,
    callbacks=[early_stopping, checkpoint]
)

test_loss, test_acc = model_gap.evaluate(
    X_test,
    y_test,
    batch_size=BATCH_SIZE,
    verbose=2
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 256, 256, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 128, 128, 128)  │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,837,382 (7.01 MB)
#  Trainable params: 1,834,950 (7.00 MB)
#  Non-trainable params: 2,432 (9.50 KB)
# Epoch 1/80
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.3594 - loss: 10.2838
# Epoch 1: val_loss improved from inf to 11.95849, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 184s 405ms/step - accuracy: 0.3595 - loss: 10.2828 - val_accuracy: 0.1607 - val_loss: 11.9585
# Epoch 2/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4719 - loss: 9.0145
# Epoch 2: val_loss improved from 11.95849 to 9.48931, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 330ms/step - accuracy: 0.4719 - loss: 9.0137 - val_accuracy: 0.3703 - val_loss: 9.4893
# Epoch 3/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.5154 - loss: 7.9011
# Epoch 3: val_loss did not improve from 9.48931
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.5155 - loss: 7.9004 - val_accuracy: 0.2809 - val_loss: 9.7324
# Epoch 4/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5528 - loss: 6.9143
# Epoch 4: val_loss did not improve from 9.48931
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.5528 - loss: 6.9136 - val_accuracy: 0.2113 - val_loss: 9.9279
# Epoch 5/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5708 - loss: 6.0264
# Epoch 5: val_loss improved from 9.48931 to 7.57683, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.5709 - loss: 6.0258 - val_accuracy: 0.2655 - val_loss: 7.5768
# Epoch 6/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6257 - loss: 5.1993
# Epoch 6: val_loss did not improve from 7.57683
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.6256 - loss: 5.1988 - val_accuracy: 0.3720 - val_loss: 7.7678
# Epoch 7/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6392 - loss: 4.5157
# Epoch 7: val_loss improved from 7.57683 to 6.87249, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.6392 - loss: 4.5153 - val_accuracy: 0.2835 - val_loss: 6.8725
# Epoch 8/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6626 - loss: 3.9308
# Epoch 8: val_loss did not improve from 6.87249
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.6626 - loss: 3.9306 - val_accuracy: 0.3411 - val_loss: 7.2369
# Epoch 9/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6778 - loss: 3.4394
# Epoch 9: val_loss improved from 6.87249 to 6.18660, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.6779 - loss: 3.4391 - val_accuracy: 0.3385 - val_loss: 6.1866
# Epoch 10/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6876 - loss: 3.0487
# Epoch 10: val_loss did not improve from 6.18660
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.6876 - loss: 3.0485 - val_accuracy: 0.3187 - val_loss: 6.6429
# Epoch 11/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7090 - loss: 2.6941
# Epoch 11: val_loss improved from 6.18660 to 5.89844, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.7090 - loss: 2.6939 - val_accuracy: 0.3883 - val_loss: 5.8984
# Epoch 12/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7228 - loss: 2.3846
# Epoch 12: val_loss improved from 5.89844 to 4.84070, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 330ms/step - accuracy: 0.7228 - loss: 2.3845 - val_accuracy: 0.4132 - val_loss: 4.8407
# Epoch 13/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7364 - loss: 2.1201
# Epoch 13: val_loss did not improve from 4.84070
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 330ms/step - accuracy: 0.7364 - loss: 2.1200 - val_accuracy: 0.4184 - val_loss: 5.1698
# Epoch 14/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7429 - loss: 1.9212
# Epoch 14: val_loss improved from 4.84070 to 3.69702, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 330ms/step - accuracy: 0.7429 - loss: 1.9211 - val_accuracy: 0.4820 - val_loss: 3.6970
# Epoch 15/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7720 - loss: 1.7069
# Epoch 15: val_loss improved from 3.69702 to 3.10999, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.7720 - loss: 1.7068 - val_accuracy: 0.4682 - val_loss: 3.1100
# Epoch 16/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7705 - loss: 1.5759
# Epoch 16: val_loss did not improve from 3.10999
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.7705 - loss: 1.5758 - val_accuracy: 0.4338 - val_loss: 4.1849
# Epoch 17/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7799 - loss: 1.4380
# Epoch 17: val_loss improved from 3.10999 to 2.98629, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 330ms/step - accuracy: 0.7798 - loss: 1.4380 - val_accuracy: 0.4751 - val_loss: 2.9863
# Epoch 18/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7937 - loss: 1.3141
# Epoch 18: val_loss did not improve from 2.98629
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.7937 - loss: 1.3140 - val_accuracy: 0.4235 - val_loss: 3.6583
# Epoch 19/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8043 - loss: 1.2023
# Epoch 19: val_loss did not improve from 2.98629
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8042 - loss: 1.2023 - val_accuracy: 0.3729 - val_loss: 4.5650
# Epoch 20/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8149 - loss: 1.1174
# Epoch 20: val_loss did not improve from 2.98629
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8148 - loss: 1.1175 - val_accuracy: 0.4682 - val_loss: 4.0095
# Epoch 21/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8189 - loss: 1.0441
# Epoch 21: val_loss improved from 2.98629 to 2.61874, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8189 - loss: 1.0441 - val_accuracy: 0.5309 - val_loss: 2.6187
# Epoch 22/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8305 - loss: 0.9577
# Epoch 22: val_loss did not improve from 2.61874
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8304 - loss: 0.9578 - val_accuracy: 0.4605 - val_loss: 3.3637
# Epoch 23/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8365 - loss: 0.9181
# Epoch 23: val_loss did not improve from 2.61874
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 330ms/step - accuracy: 0.8365 - loss: 0.9181 - val_accuracy: 0.5550 - val_loss: 2.6708
# Epoch 24/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8464 - loss: 0.8690
# Epoch 24: val_loss improved from 2.61874 to 1.98352, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8464 - loss: 0.8691 - val_accuracy: 0.5773 - val_loss: 1.9835
# Epoch 25/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8505 - loss: 0.8179
# Epoch 25: val_loss did not improve from 1.98352
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8505 - loss: 0.8180 - val_accuracy: 0.5576 - val_loss: 2.4697
# Epoch 26/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8575 - loss: 0.7697
# Epoch 26: val_loss did not improve from 1.98352
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8575 - loss: 0.7697 - val_accuracy: 0.5507 - val_loss: 2.8769
# Epoch 27/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8597 - loss: 0.7515
# Epoch 27: val_loss did not improve from 1.98352
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 328ms/step - accuracy: 0.8597 - loss: 0.7515 - val_accuracy: 0.5180 - val_loss: 2.8512
# Epoch 28/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8613 - loss: 0.7153
# Epoch 28: val_loss did not improve from 1.98352
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8613 - loss: 0.7153 - val_accuracy: 0.5782 - val_loss: 2.2761
# Epoch 29/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8855 - loss: 0.6525
# Epoch 29: val_loss improved from 1.98352 to 1.29008, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8855 - loss: 0.6525 - val_accuracy: 0.7191 - val_loss: 1.2901
# Epoch 30/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8745 - loss: 0.6500
# Epoch 30: val_loss did not improve from 1.29008
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8745 - loss: 0.6500 - val_accuracy: 0.5816 - val_loss: 2.1464
# Epoch 31/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8762 - loss: 0.6222
# Epoch 31: val_loss improved from 1.29008 to 1.27971, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.8762 - loss: 0.6222 - val_accuracy: 0.7182 - val_loss: 1.2797
# Epoch 32/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8986 - loss: 0.5590
# Epoch 32: val_loss did not improve from 1.27971
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 328ms/step - accuracy: 0.8986 - loss: 0.5590 - val_accuracy: 0.6186 - val_loss: 1.8906
# Epoch 33/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9029 - loss: 0.5545
# Epoch 33: val_loss did not improve from 1.27971
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 329ms/step - accuracy: 0.9029 - loss: 0.5545 - val_accuracy: 0.6813 - val_loss: 1.5411
# Epoch 34/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8956 - loss: 0.5581
# Epoch 34: val_loss did not improve from 1.27971
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 328ms/step - accuracy: 0.8956 - loss: 0.5581 - val_accuracy: 0.5584 - val_loss: 2.9580
# Epoch 35/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9004 - loss: 0.5439
# Epoch 35: val_loss did not improve from 1.27971
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 328ms/step - accuracy: 0.9004 - loss: 0.5439 - val_accuracy: 0.5885 - val_loss: 2.2098
# Epoch 36/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9072 - loss: 0.5003
# Epoch 36: val_loss did not improve from 1.27971
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 328ms/step - accuracy: 0.9072 - loss: 0.5004 - val_accuracy: 0.7259 - val_loss: 1.3653
# Epoch 37/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9129 - loss: 0.4854
# Epoch 37: val_loss did not improve from 1.27971
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 120s 328ms/step - accuracy: 0.9129 - loss: 0.4854 - val_accuracy: 0.5876 - val_loss: 2.3599
# 37/37 - 3s - 68ms/step - accuracy: 0.7053 - loss: 1.3861

# %% [markdown]
# # Visualization

# %% [markdown]
# Model Evaluation at baseline
#
#
# ---
#
# Comparing GAP vs Flatten Head

# %%
from tensorflow.keras.models import load_model

test_images, test_labels = test_generator_data
best_model = load_model('best_model_gap.keras')

# predictions
y_probs = best_model.predict(test_images)
y_pred = np.argmax(y_probs, axis=1)
y_true = np.argmax(test_labels, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# macro / weighted metrics
precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro    = recall_score(y_true, y_pred, average='macro')
f1_macro        = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted    = recall_score(y_true, y_pred, average='weighted')
f1_weighted        = f1_score(y_true, y_pred, average='weighted')

print(f"\nPrecision (macro):   {precision_macro:.4f}")
print(f"Recall (macro):      {recall_macro:.4f}")
print(f"F1-score (macro):    {f1_macro:.4f}")
print(f"Precision (weighted): {precision_weighted:.4f}")
print(f"Recall (weighted):    {recall_weighted:.4f}")
print(f"F1-score (weighted):  {f1_weighted:.4f}")

import matplotlib.pyplot as plt
import numpy as np

num_samples = 9
idxs = np.random.choice(len(test_images), size=num_samples, replace=False)

plt.figure(figsize=(12,12))

for i, idx in enumerate(idxs):
    img = test_images[idx]
    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]

    plt.subplot(3, 3, i+1)
    plt.imshow(img)
    plt.title(f"Pred: {pred_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    cardboard       0.90      0.50      0.64       172
#        glass       0.68      0.86      0.76       229
#        metal       0.99      0.44      0.61       162
#        paper       0.60      0.85      0.70       181
#      plastic       0.66      0.82      0.73       170
#        trash       0.72      0.69      0.71       250
#
#     accuracy                           0.71      1164
#    macro avg       0.76      0.69      0.69      1164
# weighted avg       0.75      0.71      0.70      1164
#
#
# Precision (macro):   0.7584
# Recall (macro):      0.6941
# F1-score (macro):    0.6925
# Precision (weighted): 0.7493
# Recall (weighted):    0.7053
# F1-score (weighted):  0.6976

# %%
# Confusion Matrix Visualization

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix (CNN + GAP)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
# ROC Curves

from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(8,6))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true == i, y_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f"{class_name} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], 'k--')
plt.title("ROC Curves (One-vs-Rest)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Precision–Recall Curves

from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(8,6))

for i, class_name in enumerate(class_names):
    precision, recall, _ = precision_recall_curve(y_true == i, y_probs[:, i])
    plt.plot(recall, precision, lw=2, label=f"{class_name}")

plt.title("Precision–Recall Curves")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Loss Curve Plots

# %%
train_loss = history_gap.history['loss']
val_loss   = history_gap.history['val_loss']
train_acc  = history_gap.history['accuracy']
val_acc    = history_gap.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

fig, ax = plt.subplots(1, 2, figsize=(15,5))

# LOSS
ax[0].plot(epochs, train_loss, 'b-', label='Training Loss', linewidth=2)
ax[0].plot(epochs, val_loss, 'r-', label='Validation Loss', linewidth=2)
ax[0].set_title("Loss Curve", fontsize=15)
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend()
ax[0].grid(True)

# showing final test loss on chart
ax[0].text(0.95, 0.95, f"Test Loss: {test_loss:.4f}",
           ha='right', va='top', transform=ax[0].transAxes,
           fontsize=12, color='black',
           bbox=dict(facecolor='white', alpha=0.7, edgecolor='gray'))

# ACCURACY
ax[1].plot(epochs, train_acc, 'b-', label='Training Accuracy', linewidth=2)
ax[1].plot(epochs, val_acc, 'r-', label='Validation Accuracy', linewidth=2)
ax[1].set_title("Accuracy Curve", fontsize=15)
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
ax[1].legend()
ax[1].grid(True)


ax[1].text(0.95, 0.95, f"Test Acc: {test_acc:.4f}",
           ha='right', va='top', transform=ax[1].transAxes,
           fontsize=12, color='black',
           bbox=dict(facecolor='white', alpha=0.7, edgecolor='gray'))

plt.show()
