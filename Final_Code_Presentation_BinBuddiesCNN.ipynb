# %% [markdown]
# <a href="https://colab.research.google.com/github/yvessong23/ML-TEAM-15/blob/main/Final_Code_Presentation_BinBuddiesCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import TensorFlow
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, roc_auc_score
import seaborn as sns

# %%
# %pip install numpy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import hashlib, os
from PIL import Image
# %pip install kagglehub

import kagglehub

# Download latest version
path = kagglehub.dataset_download("zlatan599/garbage-dataset-classification")
rgb_path = "cleaned/garbage-dataset-rgb"
print("Path to dataset files:", path)

hashes = {}
duplicates = []

def file_hash(filePath):
    with open(filePath, "rb") as f: # Open and read files for hashing
        file_bytes = f.read()
        return hashlib.md5(file_bytes).hexdigest()

for root, dirs, files in os.walk(path):
    for file in files:
        file_path = os.path.join(root, file)
        h = file_hash(file_path)

        if h in hashes:
            print(f"Duplicate found! Removing {file_path} (same as {hashes[h]})")
            try:
                os.remove(file_path)
                duplicates.append((file_path, hashes[h]))
            except OSError as e:
                print(f"Warning: Could not remove {file_path} due to read-only filesystem. Error: {e}")
        else:
            hashes[h] = file_path
            try:
                # Preserve the dataset’s subfolder structure
                rel_dir = os.path.relpath(root, path)
                save_dir = os.path.join(rgb_path, rel_dir)
                os.makedirs(save_dir, exist_ok=True)

                save_path = os.path.join(save_dir, file)

                # Skip non-image files (like metadata.csv)
                if not file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff")):
                    continue

                with Image.open(file_path) as img:
                    img.convert("RGB").save(save_path)

            except Exception as e:
                print(f"Error processing {file_path}: {e}")
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.11.12)
# Using Colab cache for faster access to the 'garbage-dataset-classification' dataset.
# Path to dataset files: /kaggle/input/garbage-dataset-classification
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01555.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00775.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01555.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01555.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01321.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00883.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01321.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01321.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01440.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00541.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01440.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01440.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00198.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01167.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00198.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00198.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01594.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00481.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01594.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01594.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01493.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00358.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01493.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01493.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00235.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01170.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00235.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00235.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00932.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01205.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00932.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00932.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00622.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01778.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00622.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00622.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00707.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01654.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00707.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00707.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00623.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01800.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00623.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00623.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01340.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00299.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01340.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01340.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00744.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01480.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00744.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00744.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00195.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01362.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00195.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00195.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01409.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00331.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01409.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01409.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01795.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00733.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01795.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01795.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01333.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00238.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01333.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01333.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02631.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00597.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02631.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02631.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00414.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01682.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00414.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00414.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01376.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00426.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01376.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01376.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00929.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01468.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00929.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00929.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00710.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01226.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00710.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00710.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00020.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01338.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00020.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00020.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00264.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01383.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00264.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00264.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00531.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01711.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00531.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00531.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00028.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01457.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00028.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00028.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01770.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00841.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01770.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01770.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01427.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00860.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01427.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01427.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00708.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02642.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00708.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00708.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00821.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01407.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00821.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00821.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00886.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01592.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00886.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00886.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00578.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01236.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00578.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00578.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01410.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00320.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01410.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01410.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01538.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00609.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01538.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01538.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01057.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01724.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01057.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01057.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01671.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00985.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01671.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01671.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01334.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00761.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01334.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01334.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01143.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00061.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01143.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01143.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01719.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00930.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01719.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01719.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00685.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01369.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00685.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00685.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01815.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00966.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01815.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01815.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00822.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01141.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00822.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00822.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00227.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01356.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00227.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00227.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01238.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00355.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01238.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01238.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01395.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00302.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01395.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01395.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01428.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00059.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01428.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01428.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00078.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01416.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00078.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00078.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01451.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00325.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01451.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01451.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01041.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01424.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01041.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01041.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00540.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01510.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00540.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00540.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00599.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01235.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00599.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00599.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00971.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01511.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00971.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00971.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01739.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00829.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01739.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01739.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00720.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02646.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00720.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00720.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01802.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00721.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01802.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01802.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01575.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00895.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01575.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01575.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01131.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00642.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01131.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01131.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01680.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00746.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01680.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01680.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01211.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00726.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01211.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01211.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00624.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01350.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00624.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00624.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01813.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00526.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01813.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01813.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01696.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00617.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01696.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01696.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00215.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01180.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00215.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00215.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01063.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01768.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01063.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01063.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00992.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01516.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00992.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00992.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01558.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00908.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01558.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01558.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00561.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01351.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00561.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00561.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00584.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01508.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00584.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00584.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00006.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01465.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00006.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00006.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00723.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01557.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00723.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00723.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01169.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00501.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01169.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01169.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01212.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00248.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01212.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01212.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01112.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00529.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01112.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01112.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00296.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01315.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00296.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00296.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01668.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00466.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01668.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01668.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00203.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01292.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00203.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00203.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01247.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00926.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01247.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01247.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00847.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01320.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00847.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00847.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00986.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01142.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00986.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00986.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02622.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00539.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02622.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02622.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00648.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01286.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00648.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00648.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01534.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01000.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01534.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01534.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00332.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01183.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00332.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00332.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01611.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01005.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01611.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01611.jpg'
# ...
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02793.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02017.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02793.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02793.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00972.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02785.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00972.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00972.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00571.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02802.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00571.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00571.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00951.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02385.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00951.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00951.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00667.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02706.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00667.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00667.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02810.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01838.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02810.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02810.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01319.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02618.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01319.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01319.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00996.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02770.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00996.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00996.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02115.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01238.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02115.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02115.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00971.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02205.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00971.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00971.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02726.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01125.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02726.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02726.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02105.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00463.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02105.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02105.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02556.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01817.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02556.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02556.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00766.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02555.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00766.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00766.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02503.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_03196.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02503.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02503.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02734.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00844.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02734.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02734.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02441.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00036.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02441.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02441.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00025.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02098.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00025.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00025.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01145.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02702.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01145.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01145.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02374.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00668.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02374.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02374.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02729.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_03176.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02729.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02729.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02349.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00984.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02349.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02349.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02448.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01055.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02448.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02448.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00841.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02384.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00841.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00841.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02093.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00811.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02093.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02093.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01031.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02155.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01031.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_01031.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02136.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00641.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02136.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02136.jpg'
# Duplicate found! Removing /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00787.jpg (same as /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_02250.jpg)
# Warning: Could not remove /kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00787.jpg due to read-only filesystem. Error: [Errno 30] Read-only file system: '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/plastic/plastic_00787.jpg'

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

rgb_path = "cleaned/garbage-dataset-rgb"
base_path = os.path.join(rgb_path, "Garbage_Dataset_Classification", "images")
DATASET_DIR = base_path

# Set up class names
class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
num_classes = len(class_names)

if 'duplicates' not in globals():
    duplicates = []

# Verify and collect all image paths and their labels
image_paths = []
labels = []

duplicate_filepaths = {f[0] for f in duplicates} # Extract only the file paths from the duplicates list

for class_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(base_path, class_name)
    if os.path.exists(class_dir):
        class_images = [f for f in os.listdir(class_dir)
                       if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
        print(f"{class_name}: {len(class_images)} images")

        for img_file in class_images:
            full_path = os.path.join(class_dir, img_file)
            if full_path not in duplicate_filepaths: # Only add if not a duplicate
                image_paths.append(full_path)
                labels.append(class_idx)
    else:
        print(f"Warning: {class_dir} does not exist")
# Out:
# cardboard: 1718 images
# glass: 2293 images
# metal: 1628 images
# paper: 1809 images
# plastic: 1709 images
# trash: 2500 images

# %% [markdown]
# # Hyper parameter Testing

# %%
# Hyperparameters for searching with Optuna
BLOCK_NUM = [3,4,5]
CONV_LAYERS = [1, 2, 3]
BATCH_SIZES = [16, 32, 64]
EPOCHS = [10, 20, 30]
CONV_LAYER_SIZE_BASE = [32, 64, 128]
FILTERS_SIZE = [3,5,7]
REGULARIZATION_CONST = [0.001, 0.01, 0.1]
REG_TYPE = ["n/a", "L2", "Dropout", "Both"]

# %%
# %pip install optuna
# import optuna
# import tensorflow as tf
# from tensorflow.keras import models, layers, regularizers

# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)
# BATCH_SIZE = 32
# from tensorflow.keras import models, layers
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# from sklearn.model_selection import train_test_split
# import numpy as np

# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# IMG_SIZE   = (IMG_HEIGHT, IMG_WIDTH)
# BATCH_SIZE = 32

# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     validation_split=0.3
# )

# val_test_datagen = ImageDataGenerator(
#     rescale=1./255,
#     validation_split=0.2
# )

# train_generator = train_datagen.flow_from_directory(
#     DATASET_DIR,
#     target_size=IMG_SIZE,
#     batch_size=BATCH_SIZE,
#     class_mode='categorical',
#     subset='training',
#     shuffle=True,
#     seed=42
# )

# # Load all validation images into memory, then split into val + test
# val_generator_full = val_test_datagen.flow_from_directory(
#     DATASET_DIR,
#     target_size=IMG_SIZE,
#     batch_size=1,
#     class_mode='categorical',
#     subset='validation',
#     shuffle=False,
#     seed=42
# )

# val_data = []
# val_labels = []

# for i in range(len(val_generator_full)):
#     x, y = val_generator_full[i]
#     val_data.append(x[0])
#     val_labels.append(y[0])

# val_data = np.array(val_data)
# val_labels = np.array(val_labels)

# X_val, X_test, y_val, y_test = train_test_split(
#     val_data,
#     val_labels,
#     test_size=0.5,
#     random_state=42,
#     stratify=np.argmax(val_labels, axis=1)
# )

# val_generator_data = (X_val, y_val)
# test_generator_data = (X_test, y_test)



# def build_model(trial):

#     block_num   = trial.suggest_categorical("block_num", [3, 4, 5])
#     conv_layers = trial.suggest_categorical("conv_layers", [1, 2, 3])
#     batch_size  = trial.suggest_categorical("batch_size", [16, 32, 64])
#     epochs      = trial.suggest_categorical("epochs", [10, 20, 30])
#     reg_type    = trial.suggest_categorical("reg_type", ["n/a", "L2", "Dropout", "Both"])

#     # example: choose regularizer based on reg_type
#     if reg_type in ["L2", "Both"]:
#         reg = regularizers.l2(trial.suggest_float("l2_reg", 1e-5, 1e-2, log=True))
#     else:
#         reg = None

#     dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5) if reg_type in ["Dropout", "Both"] else 0.0

#     # Hyperparameters to tune
#     f1 = trial.suggest_categorical("f1", [32, 48, 64])
#     f2 = trial.suggest_categorical("f2", [64, 96, 128])
#     f3 = trial.suggest_categorical("f3", [128, 192, 256])
#     f4 = trial.suggest_categorical("f4", [256, 384, 512])

#     d1 = trial.suggest_float("d1", 0.1, 0.4)
#     d2 = trial.suggest_float("d2", 0.1, 0.4)
#     d3 = trial.suggest_float("d3", 0.2, 0.5)
#     d4 = trial.suggest_float("d4", 0.2, 0.5)

#     dense_units = trial.suggest_categorical("dense_units", [128, 256, 512])
#     l2_reg = trial.suggest_float("l2_reg", 1e-5, 1e-2, log=True)
#     lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)

#     kernel = trial.suggest_categorical("kernel", [3, 5])

#     model = models.Sequential([
#         layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

#         layers.Conv2D(f1, (kernel, kernel), padding='same', activation='relu'),
#         layers.Conv2D(f2, (kernel, kernel), padding='same', activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dropout(d1),
#         layers.MaxPool2D(2),

#         layers.Conv2D(f3, (kernel, kernel), padding='same', activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dropout(d2),
#         layers.MaxPool2D(2),

#         layers.Conv2D(f4, (3,3), padding='same', activation='relu',
                      # kernel_regularizer=regularizers.l2(l2_reg)),
    #     layers.BatchNormalization(),
    #     layers.Dropout(d3),
    #     layers.MaxPool2D(2),

    #     layers.GlobalAveragePooling2D(),

    #     layers.Dense(dense_units, activation='relu',
    #                  kernel_regularizer=regularizers.l2(l2_reg)),
    #     layers.BatchNormalization(),
    #     layers.Dropout(d4),

    #     layers.Dense(6, activation='softmax')
    # ])

    # model.compile(
    #     optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
    #     loss='categorical_crossentropy',
    #     metrics=['accuracy']
    # )

    # return model
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 32.3 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
# def objective(trial):
#     model = build_model(trial)

#     history = model.fit(
#         train_generator,
#         validation_data=val_generator_data,
#         epochs=trial.params["epochs"],
#         batch_size=trial.params["batch_size"],
#         verbose=0
#     )

#     return history.history["val_loss"][-1]

# %%
# study = optuna.create_study(
#     direction="minimize",
#     pruner=optuna.pruners.MedianPruner(n_warmup_steps=3)
# )
# study.optimize(objective, n_trials=30)

# print("Best params:", study.best_params)

# %% [markdown]
# # Base Model Testing

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split
import numpy as np

IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_SIZE   = (IMG_HEIGHT, IMG_WIDTH)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    # rotation_range=20,
    # zoom_range=0.2,
    # horizontal_flip=True,
    # brightness_range=(0.7, 1.3)
)

val_test_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

# Load all validation images into memory, then split into val + test
val_generator_full = val_test_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=1,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=42
)

val_data = []
val_labels = []

for i in range(len(val_generator_full)):
    x, y = val_generator_full[i]
    val_data.append(x[0])
    val_labels.append(y[0])

val_data = np.array(val_data)
val_labels = np.array(val_labels)

X_val, X_test, y_val, y_test = train_test_split(
    val_data,
    val_labels,
    test_size=0.5,
    random_state=42,
    stratify=np.argmax(val_labels, axis=1)
)

val_generator_data = (X_val, y_val)
test_generator_data = (X_test, y_test)

model_gap = models.Sequential([
    layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

    # Block 1
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),
    layers.MaxPool2D(2),

    # Block 2
    layers.Conv2D(128, (5,5), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),
    layers.MaxPool2D(2),

    # Block 3
    layers.Conv2D(256, (3,3), padding='same', activation='relu',
    kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.35),
    layers.MaxPool2D(2),

    # Block 4
    layers.Conv2D(512, (3,3), padding='same', activation='relu',
    kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.35),
    layers.MaxPool2D(2),

    # Head with GAP
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.50),
    layers.Dense(6, activation='softmax'),
])
# Out:
# Found 11657 images belonging to 6 classes.
# Found 2328 images belonging to 6 classes.

# %% [markdown]
# # Testing CNN with Global Average Pooling
#
# Using ChatGPT and Kaggle, I found that GAP or Global Average Pooling can significantly reduce the number of parameters. This method compresses each feature map into a single value by averaging its activations (outputs). This reduced our dimensionality from 5+ million to about 56K. This also allows the model to generalize better and train faster.
# https://www.kaggle.com/code/faressayah/cifar-10-images-classification-using-cnns-88
# https://www.kaggle.com/code/zlatan599/f1-0-97-garbage-classif-final-version-2
#
# The baseline run of this model with no dropout, data augmentation, or hyperparameter tuning was:
#
# * Train Accuracy: ~0.76
#
# * Train Loss: ~0.81
#
# * Best Validation Accuracy: ~0.59 (epoch 27)
#
# * Best Validation Loss: ~1.43
#
# * Test Accuracy: 0.5902
#
# * Test Loss: 1.52
#
# * Training Time: ≈ 24 minutes for 30 epochs on GPU
#
# # Strong classes:
#
# Cardboard: 0.74 F1 (0.71 precision / 0.77 recall)
#
# Paper: 0.68 F1
#
# Trash: 0.64 F1
#
# # Medium:
#
# Glass: 0.61 F1
#
# # Weak:
#
# Plastic: 0.50 F1
#
# Metal: 0.40 F1

# %%
print(tf.config.list_physical_devices("GPU"))

model_gap.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model_gap.summary()

checkpoint = ModelCheckpoint(
    'best_model_gap.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)


history_gap = model_gap.fit(
    train_generator,
    validation_data=val_generator_data,
    epochs=80,
    callbacks=[early_stopping, checkpoint]
)

test_loss, test_acc = model_gap.evaluate(
    X_test,
    y_test,
    batch_size=BATCH_SIZE,
    verbose=2
)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 256, 256, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 128, 128, 128)  │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,837,382 (7.01 MB)
#  Trainable params: 1,834,950 (7.00 MB)
#  Non-trainable params: 2,432 (9.50 KB)
# Epoch 1/80
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.3560 - loss: 10.2560
# Epoch 1: val_loss improved from inf to 12.16663, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 187s 414ms/step - accuracy: 0.3561 - loss: 10.2550 - val_accuracy: 0.1469 - val_loss: 12.1666
# Epoch 2/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4598 - loss: 9.0072
# Epoch 2: val_loss improved from 12.16663 to 9.88469, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 333ms/step - accuracy: 0.4598 - loss: 9.0065 - val_accuracy: 0.2285 - val_loss: 9.8847
# Epoch 3/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.4977 - loss: 7.9065
# Epoch 3: val_loss did not improve from 9.88469
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 332ms/step - accuracy: 0.4978 - loss: 7.9057 - val_accuracy: 0.2070 - val_loss: 10.8880
# Epoch 4/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5336 - loss: 6.8859
# Epoch 4: val_loss improved from 9.88469 to 8.76575, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 332ms/step - accuracy: 0.5336 - loss: 6.8853 - val_accuracy: 0.2620 - val_loss: 8.7658
# Epoch 5/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5564 - loss: 5.9762
# Epoch 5: val_loss improved from 8.76575 to 7.37137, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 332ms/step - accuracy: 0.5564 - loss: 5.9757 - val_accuracy: 0.3093 - val_loss: 7.3714
# Epoch 6/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5963 - loss: 5.1747
# Epoch 6: val_loss did not improve from 7.37137
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 332ms/step - accuracy: 0.5963 - loss: 5.1742 - val_accuracy: 0.2354 - val_loss: 8.9602
# Epoch 7/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6183 - loss: 4.4610
# Epoch 7: val_loss improved from 7.37137 to 7.00044, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 332ms/step - accuracy: 0.6183 - loss: 4.4607 - val_accuracy: 0.3136 - val_loss: 7.0004
# Epoch 8/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6520 - loss: 3.9018
# Epoch 8: val_loss improved from 7.00044 to 5.45981, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.6520 - loss: 3.9016 - val_accuracy: 0.4107 - val_loss: 5.4598
# Epoch 9/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6584 - loss: 3.4257
# Epoch 9: val_loss did not improve from 5.45981
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.6584 - loss: 3.4254 - val_accuracy: 0.3247 - val_loss: 6.5160
# Epoch 10/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6788 - loss: 3.0026
# Epoch 10: val_loss did not improve from 5.45981
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.6788 - loss: 3.0024 - val_accuracy: 0.3445 - val_loss: 5.4719
# Epoch 11/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6988 - loss: 2.6787
# Epoch 11: val_loss improved from 5.45981 to 5.14832, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.6988 - loss: 2.6786 - val_accuracy: 0.4158 - val_loss: 5.1483
# Epoch 12/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7054 - loss: 2.3851
# Epoch 12: val_loss did not improve from 5.14832
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7055 - loss: 2.3850 - val_accuracy: 0.3548 - val_loss: 5.6806
# Epoch 13/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7371 - loss: 2.1291
# Epoch 13: val_loss improved from 5.14832 to 4.30675, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7371 - loss: 2.1290 - val_accuracy: 0.4192 - val_loss: 4.3068
# Epoch 14/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7439 - loss: 1.9195
# Epoch 14: val_loss did not improve from 4.30675
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7439 - loss: 1.9194 - val_accuracy: 0.4141 - val_loss: 4.6929
# Epoch 15/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7569 - loss: 1.7385
# Epoch 15: val_loss improved from 4.30675 to 3.31181, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7569 - loss: 1.7385 - val_accuracy: 0.4957 - val_loss: 3.3118
# Epoch 16/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7618 - loss: 1.6099
# Epoch 16: val_loss improved from 3.31181 to 3.16650, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7618 - loss: 1.6099 - val_accuracy: 0.5026 - val_loss: 3.1665
# Epoch 17/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7759 - loss: 1.4339
# Epoch 17: val_loss did not improve from 3.16650
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7759 - loss: 1.4339 - val_accuracy: 0.3900 - val_loss: 4.2282
# Epoch 18/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7826 - loss: 1.3544
# Epoch 18: val_loss did not improve from 3.16650
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7826 - loss: 1.3543 - val_accuracy: 0.4742 - val_loss: 3.8347
# Epoch 19/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7874 - loss: 1.2573
# Epoch 19: val_loss did not improve from 3.16650
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.7874 - loss: 1.2572 - val_accuracy: 0.5198 - val_loss: 3.7215
# Epoch 20/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8044 - loss: 1.1497
# Epoch 20: val_loss improved from 3.16650 to 2.42474, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8044 - loss: 1.1497 - val_accuracy: 0.5155 - val_loss: 2.4247
# Epoch 21/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8102 - loss: 1.0818
# Epoch 21: val_loss did not improve from 2.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8102 - loss: 1.0818 - val_accuracy: 0.4759 - val_loss: 3.4678
# Epoch 22/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8162 - loss: 1.0073
# Epoch 22: val_loss did not improve from 2.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.8162 - loss: 1.0073 - val_accuracy: 0.3763 - val_loss: 3.9915
# Epoch 23/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8279 - loss: 0.9415
# Epoch 23: val_loss did not improve from 2.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.8279 - loss: 0.9415 - val_accuracy: 0.4493 - val_loss: 2.8829
# Epoch 24/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8311 - loss: 0.8944
# Epoch 24: val_loss did not improve from 2.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8311 - loss: 0.8944 - val_accuracy: 0.5387 - val_loss: 2.4932
# Epoch 25/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8454 - loss: 0.8286
# Epoch 25: val_loss improved from 2.42474 to 2.17714, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8454 - loss: 0.8286 - val_accuracy: 0.5610 - val_loss: 2.1771
# Epoch 26/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8465 - loss: 0.8008
# Epoch 26: val_loss improved from 2.17714 to 2.07593, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8465 - loss: 0.8008 - val_accuracy: 0.5318 - val_loss: 2.0759
# Epoch 27/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8565 - loss: 0.7515
# Epoch 27: val_loss did not improve from 2.07593
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8565 - loss: 0.7516 - val_accuracy: 0.5361 - val_loss: 2.9409
# Epoch 28/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8614 - loss: 0.7212
# Epoch 28: val_loss did not improve from 2.07593
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8614 - loss: 0.7212 - val_accuracy: 0.5000 - val_loss: 2.5469
# Epoch 29/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8690 - loss: 0.6771
# Epoch 29: val_loss did not improve from 2.07593
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8689 - loss: 0.6771 - val_accuracy: 0.5902 - val_loss: 2.1492
# Epoch 30/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8694 - loss: 0.6592
# Epoch 30: val_loss improved from 2.07593 to 1.42474, saving model to best_model_gap.keras
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8694 - loss: 0.6592 - val_accuracy: 0.6503 - val_loss: 1.4247
# Epoch 31/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8764 - loss: 0.6375
# Epoch 31: val_loss did not improve from 1.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 330ms/step - accuracy: 0.8764 - loss: 0.6375 - val_accuracy: 0.6160 - val_loss: 1.7304
# Epoch 32/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8867 - loss: 0.5955
# Epoch 32: val_loss did not improve from 1.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8866 - loss: 0.5956 - val_accuracy: 0.5017 - val_loss: 2.7050
# Epoch 33/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8819 - loss: 0.5988
# Epoch 33: val_loss did not improve from 1.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8819 - loss: 0.5988 - val_accuracy: 0.3239 - val_loss: 9.5856
# Epoch 34/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8907 - loss: 0.5643
# Epoch 34: val_loss did not improve from 1.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8907 - loss: 0.5643 - val_accuracy: 0.4897 - val_loss: 3.7442
# Epoch 35/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8944 - loss: 0.5533
# Epoch 35: val_loss did not improve from 1.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8944 - loss: 0.5533 - val_accuracy: 0.5481 - val_loss: 3.2802
# Epoch 36/80
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8940 - loss: 0.5283
# Epoch 36: val_loss did not improve from 1.42474
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 121s 331ms/step - accuracy: 0.8940 - loss: 0.5283 - val_accuracy: 0.6271 - val_loss: 2.2650
# 37/37 - 2s - 67ms/step - accuracy: 0.6443 - loss: 1.3994

# %% [markdown]
# # Visualization

# %% [markdown]
# Model Evaluation at baseline
#
#
# ---
#
# Comparing GAP vs Flatten Head

# %%
from tensorflow.keras.models import load_model

test_images, test_labels = test_generator_data
best_model = load_model('best_model_gap.keras')

# predictions
y_probs = best_model.predict(test_images)
y_pred = np.argmax(y_probs, axis=1)
y_true = np.argmax(test_labels, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# macro / weighted metrics
precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro    = recall_score(y_true, y_pred, average='macro')
f1_macro        = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted    = recall_score(y_true, y_pred, average='weighted')
f1_weighted        = f1_score(y_true, y_pred, average='weighted')

print(f"\nPrecision (macro):   {precision_macro:.4f}")
print(f"Recall (macro):      {recall_macro:.4f}")
print(f"F1-score (macro):    {f1_macro:.4f}")
print(f"Precision (weighted): {precision_weighted:.4f}")
print(f"Recall (weighted):    {recall_weighted:.4f}")
print(f"F1-score (weighted):  {f1_weighted:.4f}")

import matplotlib.pyplot as plt
import numpy as np

num_samples = 9
idxs = np.random.choice(len(test_images), size=num_samples, replace=False)

plt.figure(figsize=(12,12))

for i, idx in enumerate(idxs):
    img = test_images[idx]
    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]

    plt.subplot(3, 3, i+1)
    plt.imshow(img)
    plt.title(f"Pred: {pred_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    cardboard       0.88      0.69      0.77       172
#        glass       0.83      0.56      0.67       229
#        metal       0.99      0.43      0.60       162
#        paper       0.72      0.77      0.75       181
#      plastic       0.35      0.92      0.50       170
#        trash       0.87      0.55      0.67       250
#
#     accuracy                           0.64      1164
#    macro avg       0.77      0.65      0.66      1164
# weighted avg       0.78      0.64      0.66      1164
#
#
# Precision (macro):   0.7719
# Recall (macro):      0.6537
# F1-score (macro):    0.6606
# Precision (weighted): 0.7801
# Recall (weighted):    0.6443
# F1-score (weighted):  0.6633

# %%
# Confusion Matrix Visualization

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix (CNN + GAP)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
# ROC Curves

from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(8,6))

for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_true == i, y_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f"{class_name} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], 'k--')
plt.title("ROC Curves (One-vs-Rest)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Precision–Recall Curves

from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(8,6))

for i, class_name in enumerate(class_names):
    precision, recall, _ = precision_recall_curve(y_true == i, y_probs[:, i])
    plt.plot(recall, precision, lw=2, label=f"{class_name}")

plt.title("Precision–Recall Curves")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Loss Curve Plots

# %%
train_loss = history_gap.history['loss']
val_loss   = history_gap.history['val_loss']
train_acc  = history_gap.history['accuracy']
val_acc    = history_gap.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

fig, ax = plt.subplots(1, 2, figsize=(15,5))

# LOSS
ax[0].plot(epochs, train_loss, 'b-', label='Training Loss', linewidth=2)
ax[0].plot(epochs, val_loss, 'r-', label='Validation Loss', linewidth=2)
ax[0].set_title("Loss Curve", fontsize=15)
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend()
ax[0].grid(True)

# showing final test loss on chart
ax[0].text(0.95, 0.95, f"Test Loss: {test_loss:.4f}",
           ha='right', va='top', transform=ax[0].transAxes,
           fontsize=12, color='black',
           bbox=dict(facecolor='white', alpha=0.7, edgecolor='gray'))

# ACCURACY
ax[1].plot(epochs, train_acc, 'b-', label='Training Accuracy', linewidth=2)
ax[1].plot(epochs, val_acc, 'r-', label='Validation Accuracy', linewidth=2)
ax[1].set_title("Accuracy Curve", fontsize=15)
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
ax[1].legend()
ax[1].grid(True)


ax[1].text(0.95, 0.95, f"Test Acc: {test_acc:.4f}",
           ha='right', va='top', transform=ax[1].transAxes,
           fontsize=12, color='black',
           bbox=dict(facecolor='white', alpha=0.7, edgecolor='gray'))

plt.show()
