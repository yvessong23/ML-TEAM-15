# %% [markdown]
# <a href="https://colab.research.google.com/github/yvessong23/ML-TEAM-15/blob/main/Copy_of_BinBuddiesCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import TensorFlow
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, roc_auc_score
import seaborn as sns

# %%
# %pip install numpy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import hashlib, os
from PIL import Image
# %pip install kagglehub
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import kagglehub

# Download latest version
path = kagglehub.dataset_download("zlatan599/garbage-dataset-classification")
rgb_path = "cleaned/garbage-dataset-rgb"
print("Path to dataset files:", path)

hashes = {}
duplicates = []

def file_hash(filePath):
    with open(filePath, "rb") as f: # Open and read files for hashing
        file_bytes = f.read()
        return hashlib.md5(file_bytes).hexdigest()

for root, dirs, files in os.walk(path):
    for file in files:
        file_path = os.path.join(root, file)
        h = file_hash(file_path)

        if h in hashes:
            print(f"Duplicate found! Removing {file_path} (same as {hashes[h]})")
            try:
                os.remove(file_path)
                duplicates.append((file_path, hashes[h]))
            except OSError as e:
                print(f"Warning: Could not remove {file_path} due to read-only filesystem. Error: {e}")
        else:
            hashes[h] = file_path
            try:
                # Preserve the dataset’s subfolder structure
                rel_dir = os.path.relpath(root, path)
                save_dir = os.path.join(rgb_path, rel_dir)
                os.makedirs(save_dir, exist_ok=True)

                save_path = os.path.join(save_dir, file)

                # Skip non-image files (like metadata.csv)
                if not file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff")):
                    continue

                with Image.open(file_path) as img:
                    img.convert("RGB").save(save_path)

            except Exception as e:
                print(f"Error processing {file_path}: {e}")
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.10.5)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/zlatan599/garbage-dataset-classification?dataset_version_number=5...
# 100%|██████████| 121M/121M [00:04<00:00, 26.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00074.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02280.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02209.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00861.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01905.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02364.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00766.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02555.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02787.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00820.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01188.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02646.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00086.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02181.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02418.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00969.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02218.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01180.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00422.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02284.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02703.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00890.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02169.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00282.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01020.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02435.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01332.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02091.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02185.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00265.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00450.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02434.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00348.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02524.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02369.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00598.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02016.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02358.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00027.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02540.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01267.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02347.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02108.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00240.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02326.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00732.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02607.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01005.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01209.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02633.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02613.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01666.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02585.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01499.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02521.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01026.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02745.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01279.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00042.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02430.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00252.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02567.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00169.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02315.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02639.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00957.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01203.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02188.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00752.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02452.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02686.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00919.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02407.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01339.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02778.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01903.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02544.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03186.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02265.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01157.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00522.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02152.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02257.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00191.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01215.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02682.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00175.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02559.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02530.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00901.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02377.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00274.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02270.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01622.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02754.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01406.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02201.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01518.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02139.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01673.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01248.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02474.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02312.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01679.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02680.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00885.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03069.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02335.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02346.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00387.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00815.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02145.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02240.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00345.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00689.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02090.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02533.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01190.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02672.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00978.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02203.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01466.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02385.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00951.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00585.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02398.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00410.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02113.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00267.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02470.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02220.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00369.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02239.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00779.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02324.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00349.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03029.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02325.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02344.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01573.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01638.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02352.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02102.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03195.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00232.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02117.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01250.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02526.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02744.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00864.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02713.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01089.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02333.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01471.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02804.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01804.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02547.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00335.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01463.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02481.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01241.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02571.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02466.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01576.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01046.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02167.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03128.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02662.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02670.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00634.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02605.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01657.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03040.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02659.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02541.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01110.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02612.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00992.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02802.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00571.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00029.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02302.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02458.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00909.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00206.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02328.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03049.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02131.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00133.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02236.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01159.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02345.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00326.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02305.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02580.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01970.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02705.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00601.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00069.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02177.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02581.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00800.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02375.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00734.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02761.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01114.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01882.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02281.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00841.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02384.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00421.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02528.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02808.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01243.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00251.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02261.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02576.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00805.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00342.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02138.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01058.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02428.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02788.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03261.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02589.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01500.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00549.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02378.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02360.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01009.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00906.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02433.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00838.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02562.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01129.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02154.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02147.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00744.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00524.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02116.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02446.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01759.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00683.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02187.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01562.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02731.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02779.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00579.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00485.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02747.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02176.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03168.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02163.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01380.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02349.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00984.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02717.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01925.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01048.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02494.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02338.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00828.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00587.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02594.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02103.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00047.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00230.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02551.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02792.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_03300.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01876.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02319.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02216.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00238.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02426.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00003.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02259.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_01423.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_00844.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/plastic/plastic_02734.jpg)
# ...
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01633.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02198.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03120.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02414.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03043.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02218.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01566.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02396.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00895.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02574.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02234.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00013.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02201.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00375.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00922.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02616.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02139.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00234.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00503.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02123.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00846.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02485.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01345.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02695.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00325.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02306.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00650.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02141.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02309.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02070.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00330.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02663.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00294.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02455.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03222.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02364.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02105.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00350.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01295.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02536.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02341.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00064.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01234.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02286.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02192.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00758.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01470.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02489.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02193.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00420.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00870.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02599.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00324.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02339.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02340.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03151.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01679.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02143.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00008.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02678.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00307.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02679.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02476.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00476.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01693.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02454.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02114.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00560.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00145.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02300.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02654.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00160.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02378.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01435.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00433.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02393.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02231.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00547.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00226.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02346.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02230.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03013.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02116.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02004.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02390.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03053.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_00202.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02314.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02191.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_01747.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02626.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03259.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03058.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02667.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02470.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02051.jpg)
# Duplicate found! Removing /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_03202.jpg (same as /root/.cache/kagglehub/datasets/zlatan599/garbage-dataset-classification/versions/5/Garbage_Dataset_Classification/images/paper/paper_02178.jpg)

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

rgb_path = "cleaned/garbage-dataset-rgb"
base_path = os.path.join(rgb_path, "Garbage_Dataset_Classification", "images")
DATASET_DIR = base_path

# Set up class names
class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
num_classes = len(class_names)

# Ensure 'duplicates' is defined. It is expected to be populated by cell WJM9MyG1JvjH.
# If cell WJM9MyG1JvjH hasn't been run, 'duplicates' will be an empty list, and thus
# no files will be filtered as duplicates in this cell.
if 'duplicates' not in globals():
    duplicates = []

# Verify and collect all image paths and their labels
image_paths = []
labels = []

duplicate_filepaths = {f[0] for f in duplicates} # Extract only the file paths from the duplicates list

for class_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(base_path, class_name)
    if os.path.exists(class_dir):
        class_images = [f for f in os.listdir(class_dir)
                       if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
        print(f"{class_name}: {len(class_images)} images")

        for img_file in class_images:
            full_path = os.path.join(class_dir, img_file)
            if full_path not in duplicate_filepaths: # Only add if not a duplicate
                image_paths.append(full_path)
                labels.append(class_idx)
    else:
        print(f"Warning: {class_dir} does not exist")
# Out:
# cardboard: 1718 images
# glass: 2292 images
# metal: 1628 images
# paper: 1809 images
# plastic: 1710 images
# trash: 2500 images

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split
import numpy as np

IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_SIZE   = (IMG_HEIGHT, IMG_WIDTH)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3
)

val_test_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

# Load all validation images into memory, then split into val + test
val_generator_full = val_test_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=1,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=42
)

val_data = []
val_labels = []

for i in range(len(val_generator_full)):
    x, y = val_generator_full[i]
    val_data.append(x[0])
    val_labels.append(y[0])

val_data = np.array(val_data)
val_labels = np.array(val_labels)

X_val, X_test, y_val, y_test = train_test_split(
    val_data,
    val_labels,
    test_size=0.5,
    random_state=42,
    stratify=np.argmax(val_labels, axis=1)
)

val_generator_data = (X_val, y_val)
test_generator_data = (X_test, y_test)

model_gap = models.Sequential([
    layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

    # Block 1
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPool2D(2),

    # Block 2
    layers.Conv2D(128, (5,5), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPool2D(2),

    # Block 3
    layers.Conv2D(256, (3,3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.MaxPool2D(2),

    # Block 4
   layers.Conv2D(512, (3,3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.MaxPool2D(2),

    # Head with GAP
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dense(6, activation='softmax'),
])


# model_flatten = models.Sequential([
#     layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

#     # Block 1
#     # Block 1
#     layers.Conv2D(32, (3,3), padding='same', activation='relu'),
#     layers.Conv2D(64, (3,3), padding='same', activation='relu'),
#     layers.BatchNormalization(),
#     layers.MaxPool2D(2),

#     # Block 2
#     layers.Conv2D(128, (5,5), padding='same', activation='relu'),
#     layers.BatchNormalization(),
#     layers.MaxPool2D(2),

#     # Block 3
#     layers.Conv2D(256, (3,3), padding='same', activation='relu',
#                   kernel_regularizer=regularizers.l2(0.01)),
#     layers.BatchNormalization(),
#     layers.MaxPool2D(2),

#     # Block 4
#    layers.Conv2D(512, (3,3), padding='same', activation='relu',
#                   kernel_regularizer=regularizers.l2(0.01)),
#     layers.BatchNormalization(),
#     layers.MaxPool2D(2),

#     # Flatten Head
#     layers.Flatten(),
#     layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
#     layers.BatchNormalization(),
#     layers.Dense(6, activation='softmax'),
# ])
# Out:
# Found 8162 images belonging to 6 classes.
# Found 2329 images belonging to 6 classes.

# %% [markdown]
# # Testing CNN model with Flattening
#
# https://www.kaggle.com/code/ahmadjaved097/multiclass-image-classification-using-cnn
#
# Flatten is used in CNNs to transition convolutional feature maps to fully connected layers. Flatten simpler unrolls all the values in the feature maps into a single vector. This can result in a large number of parameters. 5+ million in this case.
#
# * Time:
# * Val Acc:
# * Val Loss:
# * Train Acc:
# * Train Loss:

# %%
# print(tf.config.list_physical_devices("GPU"))

# early_stopping = EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     restore_best_weights=True
# )

# checkpoint = ModelCheckpoint(
#     'best_model_flatten.keras',
#     monitor='val_loss',
#     save_best_only=True,
#     mode='min',
#     verbose=1
# )
# model_flatten.compile(
#     optimizer=Adam(learning_rate=1e-3),
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# model_flatten.summary()

# history = model_flatten.fit(
#     train_generator,
#     validation_data=val_generator_data,
#     epochs=30,
#     callbacks=[early_stopping, checkpoint]
# )

# test_loss, test_acc = model_flatten.evaluate(X_test,
#     y_test,
#     batch_size=BATCH_SIZE,
#     verbose=2
# )
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 256, 256, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 128, 128, 128)  │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │    33,554,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,260,742 (134.51 MB)
#  Trainable params: 35,258,310 (134.50 MB)
#  Non-trainable params: 2,432 (9.50 KB)
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.4294 - loss: 11.3752
# Epoch 1: val_loss improved from inf to 3.56090, saving model to best_model_flatten.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 156s 445ms/step - accuracy: 0.4295 - loss: 11.3583 - val_accuracy: 0.1589 - val_loss: 3.5609
# Epoch 2/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.4778 - loss: 2.5625
# Epoch 2: val_loss improved from 3.56090 to 2.64835, saving model to best_model_flatten.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 92s 360ms/step - accuracy: 0.4778 - loss: 2.5620 - val_accuracy: 0.3247 - val_loss: 2.6484
# Epoch 3/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.4917 - loss: 2.2145
# Epoch 3: val_loss did not improve from 2.64835
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 85s 331ms/step - accuracy: 0.4917 - loss: 2.2149 - val_accuracy: 0.2543 - val_loss: 8.9101
# Epoch 4/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.4707 - loss: 3.2848
# Epoch 4: val_loss improved from 2.64835 to 2.46293, saving model to best_model_flatten.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 88s 345ms/step - accuracy: 0.4707 - loss: 3.2828 - val_accuracy: 0.4107 - val_loss: 2.4629
# Epoch 5/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5322 - loss: 2.1034
# Epoch 5: val_loss improved from 2.46293 to 2.26320, saving model to best_model_flatten.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 96s 378ms/step - accuracy: 0.5321 - loss: 2.1033 - val_accuracy: 0.4828 - val_loss: 2.2632
# Epoch 6/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5301 - loss: 1.9411
# Epoch 6: val_loss improved from 2.26320 to 2.20034, saving model to best_model_flatten.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 97s 379ms/step - accuracy: 0.5300 - loss: 1.9412 - val_accuracy: 0.4270 - val_loss: 2.2003
# Epoch 7/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5357 - loss: 1.9727
# Epoch 7: val_loss did not improve from 2.20034
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 85s 331ms/step - accuracy: 0.5357 - loss: 1.9734 - val_accuracy: 0.3617 - val_loss: 2.8095
# Epoch 8/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.5230 - loss: 2.0178
# Epoch 8: val_loss did not improve from 2.20034
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 85s 330ms/step - accuracy: 0.5230 - loss: 2.0186 - val_accuracy: 0.2904 - val_loss: 3.4192
# Epoch 9/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5369 - loss: 2.3548
# Epoch 9: val_loss did not improve from 2.20034
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - accuracy: 0.5368 - loss: 2.3548 - val_accuracy: 0.1607 - val_loss: 78.0164
# Epoch 10/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.4909 - loss: 4.3585
# Epoch 10: val_loss did not improve from 2.20034
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - accuracy: 0.4909 - loss: 4.3549 - val_accuracy: 0.3600 - val_loss: 2.7870
# Epoch 11/30
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5162 - loss: 2.3482
# Epoch 11: val_loss did not improve from 2.20034
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - accuracy: 0.5162 - loss: 2.3479 - val_accuracy: 0.3385 - val_loss: 2.6390
# 37/37 - 8s - 212ms/step - accuracy: 0.4180 - loss: 2.2078

# %% [markdown]
# # Testing CNN with Global Average Pooling
#
# Using ChatGPT and Kaggle, I found that GAP or Global Average Pooling can significantly reduce the number of parameters. This method compresses each feature map into a single value by averaging its activations (outputs). This reduced our dimensionality from 5+ million to about 56K. This also allows the model to generalize better and train faster.
# https://www.kaggle.com/code/faressayah/cifar-10-images-classification-using-cnns-88
# https://www.kaggle.com/code/zlatan599/f1-0-97-garbage-classif-final-version-2
#
# The baseline run of this model with no dropout, data augmentation, or hyperparameter tuning was:
#
# * Time:
# * Val Acc:
# * Val Loss:
# * Train Acc:
# * Train Loss:

# %%
# print(tf.config.list_physical_devices("GPU"))

# model_gap.compile(
#     optimizer=Adam(learning_rate=1e-3),
#     loss='categorical_crossentropy',
#     metrics=['accuracy'],
# )

# model_gap.summary()


# early_stopping = EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     restore_best_weights=True
# )

# checkpoint = ModelCheckpoint(
#     'best_model_gap.keras',
#     monitor='val_loss',
#     save_best_only=True,
#     mode='min',
#     verbose=1
# )

# history_gap = model_gap.fit(
#     train_generator,
#     validation_data=val_generator_data,
#     epochs=30,
#     callbacks=[early_stopping, checkpoint]
# )

# test_loss, test_acc = model_gap.evaluate(
#     X_test,
#     y_test,
#     batch_size=BATCH_SIZE,
#     verbose=2
# )

# %% [markdown]
# Model Evaluation at baseline
#
#
# ---
#
# Comparing GAP vs Flatten Head

# %%
test_images, test_labels = test_generator_data

y_probs = model_gap.predict(test_images)

y_pred = np.argmax(y_probs, axis=1)
y_true = np.argmax(test_labels, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

# %%
# test_images, test_labels = test_generator_data

# y_probs = model_flatten.predict(test_images)

# y_pred = np.argmax(y_probs, axis=1)
# y_true = np.argmax(test_labels, axis=1)

# cm = confusion_matrix(y_true, y_pred)
# print("Confusion Matrix:\n", cm)

# print("\nClassification Report:")
# print(classification_report(y_true, y_pred, target_names=class_names))

# precision_macro = precision_score(y_true, y_pred, average='macro')
# recall_macro = recall_score(y_true, y_pred, average='macro')
# f1_macro = f1_score(y_true, y_pred, average='macro')

# precision_weighted = precision_score(y_true, y_pred, average='weighted')
# recall_weighted = recall_score(y_true, y_pred, average='weighted')
# f1_weighted = f1_score(y_true, y_pred, average='weighted')
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step
# Confusion Matrix:
#  [[151   8   4   3   0   6]
#  [ 26  88  12  48   7  48]
#  [ 23  22  51  19   4  43]
#  [ 36   4  64  48   4  25]
#  [ 14  34  18  27  34  44]
#  [ 24  24  56  24   7 115]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    cardboard       0.55      0.88      0.68       172
#        glass       0.49      0.38      0.43       229
#        metal       0.25      0.31      0.28       162
#        paper       0.28      0.27      0.27       181
#      plastic       0.61      0.20      0.30       171
#        trash       0.41      0.46      0.43       250
#
#     accuracy                           0.42      1165
#    macro avg       0.43      0.42      0.40      1165
# weighted avg       0.43      0.42      0.40      1165
