# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import hashlib, os

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import kagglehub

# Download latest version
path = kagglehub.dataset_download("zlatan599/garbage-dataset-classification")
print("Path to dataset files:", path)

hashes = {}
duplicates = []

def file_hash(filePath):
    with open(filePath, "rb") as f: # Open and read files for hashing
        file_bytes = f.read()
        return hashlib.md5(file_bytes).hexdigest()

for root, dirs, files in os.walk(path):
    for file in files:
        file_path = os.path.join(root, file)
        h = file_hash(file_path)

        if h is hashes:
            print(f"Duplicate found! Removing {file_path} (same as {hashes[h]})")
            os.remove(file_path)
            duplicates.append((file_path, hashes[h]))
        else:
            hashes[h] = file_path


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Path to dataset files: /kaggle/input/garbage-dataset-classification

# %%
import imagehash
from PIL import Image

import collections
hashes = collections.defaultdict(list)
path = kagglehub.dataset_download("zlatan599/garbage-dataset-classification")
print("Path to dataset files:", path)
valid_exts = {".jpg", ".jpeg", ".png", ".bmp", ".tiff"}

for root, _, files in os.walk(path):
    for file in files:
        if os.path.splitext(file)[1].lower() not in valid_exts:
            continue  # skip non-image files like .csv
        file_path = os.path.join(root, file)
        try:
            with Image.open(file_path) as img:
                h = imagehash.phash(img)  # perceptual hash
                hashes[str(h)].append(file_path)
        except UnidentifiedImageError:
            print("Skipping unreadable file:", file_path)

# Show groups of near-duplicates
#for h, files in hashes.items():
#    if len(files) > 1:
#        print("Near duplicates:", files)
# Out:
# Path to dataset files: /kaggle/input/garbage-dataset-classification
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01381.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00592.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00775.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01555.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00320.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01410.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00883.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01321.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01744.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00444.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01800.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00623.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01017.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01532.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01078.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01120.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01164.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00129.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00577.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01776.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00791.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02620.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00299.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01340.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00771.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01727.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00339.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01387.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00782.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01598.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01180.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00215.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00597.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02631.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01676.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00728.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00082.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01188.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00469.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02640.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01000.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01534.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01607.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00813.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01170.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00235.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01654.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00707.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01335.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00846.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00941.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01176.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00772.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02635.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00272.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01282.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01711.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00531.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00557.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01443.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02686.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02656.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00547.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01125.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01161.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00318.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01632.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00680.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00503.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01537.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01403.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00991.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02649.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01062.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01031.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01520.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02647.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00810.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00036.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01488.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00157.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01371.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00766.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02639.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00558.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01801.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01345.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00148.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00765.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01774.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00631.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02608.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00609.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01538.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00761.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01334.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00521.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01445.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00938.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01136.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01353.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00142.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00535.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01643.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01187.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00636.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01524.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00904.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00740.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02627.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00764.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01681.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01457.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00028.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00694.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01603.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01812.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00997.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01286.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00648.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01129.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00408.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00481.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01594.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01356.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00227.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02609.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00936.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01305.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00189.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02633.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00748.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00824.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01605.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01796.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02696.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00168.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01398.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01468.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00929.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01315.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00296.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00405.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01113.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_02632.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00874.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01673.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00439.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01803.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00857.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01338.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00020.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00358.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01493.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01489.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00125.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01269.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00861.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00966.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01815.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01266.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00832.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01318.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00114.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00025.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01307.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01122.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00211.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00926.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01247.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00840.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01627.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00639.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01386.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01510.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00540.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00480.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01514.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00468.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01701.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01663.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00625.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00669.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01498.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00526.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01813.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01167.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00198.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00355.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01238.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00015.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01163.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01354.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01040.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00400.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01425.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00706.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01805.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_01502.jpg', '/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_00360.jpg']
# Near duplicates: ['/kaggle/input/garbage-dataset-classification/Garbage_Dataset_Classification/images/metal/metal_